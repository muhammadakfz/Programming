# %% [markdown]
# #**Tanpa Ekspektasi**

# %% [markdown]
# Install repositories

# %% [markdown]
# import library dan direktori

# %%
import pandas as pd
import scipy as sp
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# *mengambil* data sample

# %%
df = pd.read_csv('air_polution.csv')
df
# Out:
#                         Country              City  AQI Value AQI Category  \
# 0            Russian Federation        Praskoveya         51     Moderate
# 1                        Brazil  Presidente Dutra         41         Good
# 2                         Italy   Priolo Gargallo         66     Moderate
# 3                        Poland         Przasnysz         34         Good
# 4                        France          Punaauia         22         Good
# ...                         ...               ...        ...          ...
# 23458                     India      Gursahaiganj        184    Unhealthy
# 23459                    France            Sceaux         50         Good
# 23460                     India          Mormugao         50         Good
# 23461  United States of America       Westerville         71     Moderate
# 23462                  Malaysia            Marang         70     Moderate
#
#        CO AQI Value CO AQI Category  Ozone AQI Value Ozone AQI Category  \
# ...

# %%
# Sort the DataFrame by AQI values in descending order
df_sorted = df.sort_values(by='AQI Value', ascending=False)

# Initialize variables
top_countries = []
top_5_countries = []

# Iterate through the sorted DataFrame
for index, row in df_sorted.iterrows():
    country = row['Country']
    if country not in top_countries:
        top_countries.append(country)
        top_5_countries.append(row)
    
    # If we have collected data for 5 different countries, exit the loop
    if len(top_5_countries) == 5:
        break

# Create a countplot
plt.figure(figsize=(10, 6))
sns.set(style="whitegrid")
sns.barplot(y="AQI Value", x="Country", data=pd.DataFrame(top_5_countries), palette="ch:start=.2,rot=-.3")

# Customize the plot
plt.title("Top 5 Countries with Highest Average AQI Values")
plt.ylabel("AQI Value")
plt.xlabel("Country")

# Show the plot
plt.show()

# %%
df.isnull().sum()
# Out:
# Country               427
# City                    1
# AQI Value               0
# AQI Category            0
# CO AQI Value            0
# CO AQI Category         0
# Ozone AQI Value         0
# Ozone AQI Category      0
# NO2 AQI Value           0
# NO2 AQI Category        0
# PM2.5 AQI Value         0
# PM2.5 AQI Category      0
# dtype: int64

# %%
df.dropna()
df.shape
# Out:
# (23463, 12)

# %%
sns.set(style='whitegrid')
plt.figure(figsize=(10, 5))
sns.countplot(x='AQI Value', data=df)
plt.xlabel('AQI Value')
plt.ylabel('Count')
plt.title('Countplot of AQI Values')
plt.show()

# %%
sns.set(style='whitegrid')
plt.figure(figsize=(10, 6))
sns.countplot(x='CO AQI Value', data=df)
plt.xlabel('CO AQI Value')
plt.ylabel('Count')
plt.title('Countplot of CO AQI Values')
plt.show()

# %%
sns.set(style='whitegrid')
plt.figure(figsize=(10, 6))
sns.countplot(x='Ozone AQI Value', data=df)
plt.xlabel('Ozone AQI Value')
plt.ylabel('Count')
plt.title('Countplot of Ozone AQI Values')
plt.show()

# %%
sns.set(style='whitegrid')
plt.figure(figsize=(10, 6))
sns.countplot(x='NO2 AQI Value', data=df)
plt.xlabel('NO2 AQI Value')
plt.ylabel('Count')
plt.title('Countplot of NO2 AQI Values')
plt.show()

# %%
sns.set(style='whitegrid')
plt.figure(figsize=(10, 6))
sns.countplot(x='PM2.5 AQI Value', data=df)
plt.xlabel('PM2.5 AQI Value')
plt.ylabel('Count')
plt.title('Countplot of PM2.5 AQI Values')
plt.show()

# %%
sns.set(style='whitegrid')
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='Country', order=df['Country'].head().value_counts().index)
plt.xlabel('Country')
plt.ylabel('Count')
plt.title('Countplot of Country')
plt.show()

# %%
sns.set(style='whitegrid')
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='City', order=df['City'].head().value_counts().index)
plt.xlabel('City')
plt.ylabel('Count')
plt.title('Countplot of City')
plt.show()

# %%
sns.set(style='whitegrid')
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='AQI Category', order=df['AQI Category'].value_counts().index)
plt.xlabel('AQI Category')
plt.ylabel('Count')
plt.title('Countplot of AQI Category')
plt.show()

# %%
col = ['AQI Value', 'CO AQI Value', 'Ozone AQI Value', 'NO2 AQI Value', 'PM2.5 AQI Value']
fig = plt.figure(figsize=(10, 6))

for i in range(len(col)):
  plt.subplot(1,5,i+1)
  plt.title(col[i])
  sns.histplot(df, x = df[col[i]])
plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(20,10))

for i in range(len(col)):
  plt.subplot(2,3,i+1)
  plt.title(col[i])
  sns.boxplot(data = df, x = df[col[i]], y = df['AQI Category'])
plt.tight_layout()
plt.show()

# %%
sns.pairplot(df)

# %%
# create scatterplot AQI Value vs PM2.5 aqi value
sns.scatterplot(data=df, x='AQI Value', y='PM2.5 AQI Value')
# Out:
# <AxesSubplot:xlabel='AQI Value', ylabel='PM2.5 AQI Value'>

# %%
sns.heatmap(df.corr(),annot=True, cbar=False, cmap='Blues', fmt='.2f');

# %%
sns.lmplot(data=df,y='Ozone AQI Value',x='AQI Value',hue="AQI Category");

# %%
sns.lmplot(data=df,y='NO2 AQI Value',x='AQI Value',hue="AQI Category");

# %%
sns.lmplot(data=df,y='CO AQI Value',x='AQI Value',hue="AQI Category");

# %%
corr = df.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, cmap='Blues', fmt='.2f')
plt.show()

# %%
# analyzing the data
df['AQI Category'].value_counts()

df['AQI Category'].value_counts().plot(kind='pie', autopct='%1.1f%%', figsize=(10, 8))
plt.title('AQI Category')
plt.show()

# %%
# Sort the DataFrame by AQI values in descending order
df_sorted = df.sort_values(by='AQI Value', ascending=False)

# Initialize variables
top_countries = []
top_5_countries = []

# Iterate through the sorted DataFrame
for index, row in df_sorted.iterrows():
    country = row['Country']
    if country not in top_countries:
        top_countries.append(country)
        top_5_countries.append(row)
    
    # If we have collected data for 5 different countries, exit the loop
    if len(top_5_countries) == 5:
        break

# Create a countplot
plt.figure(figsize=(10, 6))
sns.set(style="whitegrid")
sns.barplot(x="AQI Value", y="Country", data=pd.DataFrame(top_5_countries), palette="ch:start=.2,rot=-.3")

# Customize the plot
plt.title("Top 5 Countries with Highest AQI Values")
plt.xlabel("AQI Value")
plt.ylabel("Country")

# Show the plot
plt.show()

# %%
# Sort the DataFrame by AQI values in descending order
df_sorted = df.sort_values(by='PM2.5 AQI Value', ascending=False)

# Initialize variables
top_countries = []
top_5_countries = []

# Iterate through the sorted DataFrame
for index, row in df_sorted.iterrows():
    country = row['Country']
    if country not in top_countries:
        top_countries.append(country)
        top_5_countries.append(row)
    
    # If we have collected data for 5 different countries, exit the loop
    if len(top_5_countries) == 5:
        break

# Create a countplot
plt.figure(figsize=(10, 6))
sns.set(style="whitegrid")
sns.barplot(y="PM2.5 AQI Value", x="Country", data=pd.DataFrame(top_5_countries), palette="ch:start=.2,rot=-.3")

# Customize the plot
plt.title("Top 5 Countries with Highest PM2.5 AQI Values")
plt.xlabel("PM2.5 AQI Value")
plt.ylabel("Country")
# Customize colorbar to blue


# Show the plot
plt.show()

# %%
# Sort the DataFrame by AQI values in descending order
df_sorted = df.sort_values(by='AQI Value', ascending=False)

# Initialize variables
top_countries = []
top_5_countries = []

# Iterate through the sorted DataFrame
for index, row in df_sorted.iterrows():
    country = row['Country']
    if country not in top_countries:
        top_countries.append(country)
        top_5_countries.append(row)
    
    # If we have collected data for 5 different countries, exit the loop
    if len(top_5_countries) == 5:
        break

# Create a countplot
plt.figure(figsize=(10, 6))
sns.set(style="whitegrid")
sns.barplot(y="AQI Value", x="Country", data=pd.DataFrame(top_5_countries), palette="ch:start=.2,rot=-.3")

# Customize the plot
plt.title("Top 5 Countries with Highest AQI Values")
plt.xlabel("AQI Value")
plt.ylabel("Country")

# Show the plot
plt.show()

# %%
import sklearn.linear_model as linear_model
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.scatterplot(data=df, x='AQI Value', y='PM2.5 AQI Value')
# Out:
# <AxesSubplot:xlabel='AQI Value', ylabel='PM2.5 AQI Value'>

# %%
aqi_value = df['AQI Value'].values.reshape(-1, 1)
lign_reg = linear_model.LinearRegression()
lign_reg.fit(aqi_value, df['PM2.5 AQI Value'])
# Out:
# LinearRegression()

# %%
# Plot the regression line
plt.scatter(aqi_value, df['PM2.5 AQI Value'])
plt.plot(aqi_value, lign_reg.predict(aqi_value), color='red')
plt.xlabel('AQI Value')
plt.ylabel('PM2.5 AQI Value')
plt.show()
